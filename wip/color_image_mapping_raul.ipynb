# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from pylab import *
#import array
#import mahotas
# %matplotlib inline

# %%
l=0
k=0
#for k in range(255):
N=range(254)#k
#array.array('I')
a=zeros((len(N),len(N),3))
for i in N:
    for j in N:
        a[j][i]=array([(l//(j+1)*(j+i)//2*i//2)*2+10*j,0*j*i,0*j*i*i])
        a[i][i]=array([0,0,0])
        a[-i][i]=array([0,0,0])
        a[len(N)//2][j]=array([0,0,0])
        a[j][len(N)//2]=array([0,0,0])
        l+=1
#print a
a.astype(int)
fig = plt.figure(figsize=(15, 10))
b = fig.add_subplot(1, 1, 1)
b.set_title('rango de k-{}'.format(k))
imgplot = plt.imshow(a)
plt.show()

# %%
l=0
k=0
#for k in range(255):
N=range(254)#k
#array.array('I')
a=zeros((len(N),len(N),3))
for i in N:
    for j in N:
        a[j][i]=array([l//(j+1)*j//2*i//2,2*j*i,2*j*i*i])
        a[i][i]=array([0,l*i,0])
        a[-i][i-1]=array([0,l*i,0])
        a[len(N)//2][j]=array([0,i*i,0])
        a[j][len(N)//2]=array([0,j*j,0])
        l+=1
#print a
a.astype(int)
fig = plt.figure(figsize=(15, 10))
b = fig.add_subplot(1, 1, 1)
b.set_title('rango de k-{}'.format(k))
imgplot = plt.imshow(a)
plt.show()

# %%
l=0
k=0
#for k in range(255):
N=range(0,800)#k
#array.array('I')
a=zeros((len(N),len(N),3))
for i in N:
    for j in N:
        a[i][j]=array([j,i,l])
        l+=1
#print a
a.astype(int)
fig = plt.figure(figsize=(15, 10))
b = fig.add_subplot(1, 1, 1)
b.set_title('rango de k-{}'.format(k))
imgplot = plt.imshow(a)
plt.show()
